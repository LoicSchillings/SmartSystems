# %%
import cv2
from IPython.display import display, Image

cap = cv2.VideoCapture(0)
ret, frame = cap.read()
cap.release()

if ret:
    print("Camera werkt!")
    _, jpeg = cv2.imencode(".jpg", frame)
    display(Image(data=jpeg))
else:
    print("Kan geen frame lezen...")
# Out:
# Camera werkt!

# %%
import cv2
from IPython.display import display, Image

var = 0 # 0 = camera foto, 1 = geuploade foto, 2 = live camera feed

if var == 0:
    cap = cv2.VideoCapture(0)
    ret, frame = cap.read()
    cap.release()

    if ret:
        print("Camera werkt!")
        _, jpeg = cv2.imencode(".jpg", frame)
        display(Image(data=jpeg))
    else:
        print("Kan geen frame lezen...")
    
elif var == 1:
    image_path = "my_image.jpg"  # bestand in Jupyter
    img = cv2.imread(image_path)

else:
    print("Geen methode geselecteerd")
